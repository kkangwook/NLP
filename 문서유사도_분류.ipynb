# %% [markdown]
# # 벡터 유사도
# ![image.png](attachment:e9aaa95a-50af-4d26-81d9-acf2cc11f34f.png)
# ## 각각 값이 -1, 0, 1

# %% [markdown]
# # 1. bag or words(BOW)
# ### 불용어제거 후 여러 문장들의 토큰들 나열 후 빈도 수를 벡터화
# ### 이 정보들을 통해 벡터 유사도 사용해 유사성 분석(최대값=1)
# ![image.png](attachment:0275eb03-096f-40ee-81cb-9c5ce70f8d32.png)
# ![image.png](attachment:8322da50-f858-4f5b-aa3a-447dedc73e1c.png)
# ### 클수록 유사하다

# %% [markdown]
# # 2. Euclidean Metric(벡터 간의 거리)
# ![image.png](attachment:8315ab59-8e99-434c-903c-c9225f61c1c0.png)
# ### d길이를 통해 값이 작을수록 유사도 큼

# %% [markdown]
# # 3. levenshtein distance
# ![image.png](attachment:2dceb0af-3dd8-426c-9fd2-ecdc52e30aeb.png)
# ### 위에서 밑으로 수정하는데 5번 필요
# ---
# ---
# ---

# %% [markdown]
# ![image.png](attachment:eff33ca3-f2b7-475f-bd14-c662f41aa8f1.png)
# ## 맨윗줄은 012345
# ## 1행1열은 데와 데 비교
# ## 1행 2열은 데이와 데 비교
# ## 1행3열은 데이타와 데 비교->쭉 감
# ## 2행 1열은 데와 데이 비교-> 쭉 감
# # 마지막 열 마지막 행이 최종적인 레벤슈타인 거리!!!

# %% [markdown]
# # 4. jaccard distance
# ## 집합사이의 원소의 특징을 비교 by 개수
# ![image.png](attachment:26d5ea70-d08a-4201-9057-70be1a444244.png)
# ## 교집합개수/합집합개수

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 예시1) TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# 예시 문서들
documents = [
    "나는 파이썬을 좋아해요.",
    "파이썬은 프로그래밍 언어입니다.",
    "자바는 다른 프로그래밍 언어입니다."
]

# TF-IDF 벡터화
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)

# 첫 번째 문서와 나머지 문서들의 유사도 계산 (코사인 유사도)
cos_sim = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix)

# 결과 출력
print("문서 1과 다른 문서들 간의 코사인 유사도:", cos_sim)
# Out:
# 문서 1과 다른 문서들 간의 코사인 유사도: [[1. 0. 0.]]
